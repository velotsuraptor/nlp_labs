# %% [markdown]
# # EDA: UD Ukrainian-IU
#
# Use this notebook after running `python -m src.preprocess`.
#
# Suggested checks:
# - split sizes
# - label distribution
# - sentence-length distribution
# - OOV rate on dev/test
# - examples of difficult cases

# %%
from pathlib import Path
import json
import pandas as pd

base = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
processed = base / 'data' / 'processed'
tokens = pd.read_csv(processed / 'tokens.csv')
stats = json.loads((processed / 'dataset_stats.json').read_text(encoding='utf-8'))
tokens.head(), stats
